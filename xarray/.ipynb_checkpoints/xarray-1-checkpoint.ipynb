# %% [markdown]
# # Xarray 数据处理（１）

# %% [markdown]
# ## 1. DataArray

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# 一个简单的没有维度和坐标的 DataArray

# %%
da = xr.DataArray([9, 0, 2, 1, 0])
da
# Out:
# <xarray.DataArray (dim_0: 5)>
# array([9, 0, 2, 1, 0])
# Dimensions without coordinates: dim_0

# %%
da.plot(marker='o')

# %% [markdown]
# 加上维度名字

# %%
da = xr.DataArray([9, 0, 2, 1, 0], dims=['x'])
da
# Out:
# <xarray.DataArray (x: 5)>
# array([9, 0, 2, 1, 0])
# Dimensions without coordinates: x

# %%
da.plot(marker='o')

# %% [markdown]
# 如果加上坐标，情况会如何呢？

# %%
da = xr.DataArray([9, 0, 2, 1, 0],
                  dims=['year'],
                  coords={'year':[2010,2011,2012,2013,2014]})
da
# Out:
# <xarray.DataArray (year: 5)>
# array([9, 0, 2, 1, 0])
# Coordinates:
#   * year     (year) int64 2010 2011 2012 2013 2014

# %%
from matplotlib.ticker import MaxNLocator

f = plt.figure()
da.plot(marker='o')
ax = f.gca()

#ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda i, loc: "{:}".format(int(i)))) 
ax.xaxis.set_major_locator(MaxNLocator(5,integer=True))

# %% [markdown]
# ### 多维 DataArray

# %%
S = [[1,2,4],[5,6,7]]
levels = [0,1]
date = ['2015-09-01','2015-10-01','2015-11-01']

da = xr.DataArray(S, dims=['level', 'date'],
                           coords={'level': levels,
                                   'date': date},)
da
# Out:
# <xarray.DataArray (level: 2, date: 3)>
# array([[1, 2, 4],
#        [5, 6, 7]])
# Coordinates:
#   * level    (level) int64 0 1
#   * date     (date) <U10 '2015-09-01' '2015-10-01' '2015-11-01'

# %%
air_temp = xr.tutorial.load_dataset('air_temperature')

# %%
air_temp.air
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)>
# array([[[241.2    , 242.5    , 243.5    , ..., 232.79999, 235.5    ,
#          238.59999],
#         [243.79999, 244.5    , 244.7    , ..., 232.79999, 235.29999,
#          239.29999],
#         [250.     , 249.79999, 248.89   , ..., 233.2    , 236.39   ,
#          241.7    ],
#         ...,
#         [296.6    , 296.19998, 296.4    , ..., 295.4    , 295.1    ,
#          294.69998],
#         [295.9    , 296.19998, 296.79   , ..., 295.9    , 295.9    ,
#          295.19998],
#         [296.29   , 296.79   , 297.1    , ..., 296.9    , 296.79   ,
#          296.6    ]],
#
#        [[242.09999, 242.7    , 243.09999, ..., 232.     , 233.59999,
#          235.79999],
#         [243.59999, 244.09999, 244.2    , ..., 231.     , 232.5    ,
#          235.7    ],
#         [253.2    , 252.89   , 252.09999, ..., 230.79999, 233.39   ,
#          238.5    ],
#         ...,
#         [296.4    , 295.9    , 296.19998, ..., 295.4    , 295.1    ,
#          294.79   ],
#         [296.19998, 296.69998, 296.79   , ..., 295.6    , 295.5    ,
#          295.1    ],
#         [296.29   , 297.19998, 297.4    , ..., 296.4    , 296.4    ,
#          296.6    ]],
#
#        [[242.29999, 242.2    , 242.29999, ..., 234.29999, 236.09999,
#          238.7    ],
#         [244.59999, 244.39   , 244.     , ..., 230.29999, 232.     ,
#          235.7    ],
#         [256.19998, 255.5    , 254.2    , ..., 231.2    , 233.2    ,
#          238.2    ],
#         ...,
#         [295.6    , 295.4    , 295.4    , ..., 296.29   , 295.29   ,
#          295.     ],
#         [296.19998, 296.5    , 296.29   , ..., 296.4    , 296.     ,
#          295.6    ],
#         [296.4    , 296.29   , 296.4    , ..., 297.     , 297.     ,
#          296.79   ]],
#
#        ...,
#
#        [[243.48999, 242.98999, 242.09   , ..., 244.18999, 244.48999,
#          244.89   ],
#         [249.09   , 248.98999, 248.59   , ..., 240.59   , 241.29   ,
#          242.68999],
#         [262.69   , 262.19   , 261.69   , ..., 239.39   , 241.68999,
#          245.18999],
#         ...,
#         [294.79   , 295.29   , 297.49   , ..., 295.49   , 295.38998,
#          294.69   ],
#         [296.79   , 297.88998, 298.29   , ..., 295.49   , 295.49   ,
#          294.79   ],
#         [298.19   , 299.19   , 298.79   , ..., 296.09   , 295.79   ,
#          295.79   ]],
#
#        [[245.79   , 244.79   , 243.48999, ..., 243.29   , 243.98999,
#          244.79   ],
#         [249.89   , 249.29   , 248.48999, ..., 241.29   , 242.48999,
#          244.29   ],
#         [262.38998, 261.79   , 261.29   , ..., 240.48999, 243.09   ,
#          246.89   ],
#         ...,
#         [293.69   , 293.88998, 295.38998, ..., 295.09   , 294.69   ,
#          294.29   ],
#         [296.29   , 297.19   , 297.59   , ..., 295.29   , 295.09   ,
#          294.38998],
#         [297.79   , 298.38998, 298.49   , ..., 295.69   , 295.49   ,
#          295.19   ]],
#
#        [[245.09   , 244.29   , 243.29   , ..., 241.68999, 241.48999,
#          241.79   ],
#         [249.89   , 249.29   , 248.39   , ..., 239.59   , 240.29   ,
#          241.68999],
#         [262.99   , 262.19   , 261.38998, ..., 239.89   , 242.59   ,
#          246.29   ],
#         ...,
#         [293.79   , 293.69   , 295.09   , ..., 295.29   , 295.09   ,
#          294.69   ],
#         [296.09   , 296.88998, 297.19   , ..., 295.69   , 295.69   ,
#          295.19   ],
#         [297.69   , 298.09   , 298.09   , ..., 296.49   , 296.19   ,
#          295.69   ]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %% [markdown]
# ## 2. DataSet

# %%
air_temp
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 241.2 242.5 243.5 ... 296.49 296.19 295.69
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [markdown]
# ### 坐标 vs. 变量

# %%
air_temp*100
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
# Data variables:
#     air      (time, lat, lon) float32 24120.0 24250.0 ... 29619.0 29569.0
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [markdown]
# ## 3. 数组访问方法

# %%
air_temp.air[0,0,0]
# 等同于　
#air_temp.air.isel(lat=0,lon=0,time=0)
# Out:
# <xarray.DataArray 'air' ()>
# array(241.2, dtype=float32)
# Coordinates:
#     lat      float32 75.0
#     lon      float32 200.0
#     time     datetime64[ns] 2013-01-01
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
air_temp.air.sel(lat=50,lon=300,time='2013-12-01T00:00:00')
# Out:
# <xarray.DataArray 'air' ()>
# array(265.4, dtype=float32)
# Coordinates:
#     lat      float32 50.0
#     lon      float32 300.0
#     time     datetime64[ns] 2013-12-01
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
# slice 选取坐标范围
air_temp.air.sel(lat=50,lon=300,time=slice('2013-12-01T00:00:00','2013-12-02T00:00:00'))
# Out:
# <xarray.DataArray 'air' (time: 5)>
# array([265.4    , 267.79   , 268.19998, 269.6    , 268.79   ],
#       dtype=float32)
# Coordinates:
#     lat      float32 50.0
#     lon      float32 300.0
#   * time     (time) datetime64[ns] 2013-12-01 2013-12-01T06:00:00 ... 2013-12-02
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
air_temp.air.sel(lat=73,lon=300,time='2013-12-02T00:00:00',method='nearest')
# Out:
# <xarray.DataArray 'air' ()>
# array(259.69998, dtype=float32)
# Coordinates:
#     lat      float32 72.5
#     lon      float32 300.0
#     time     datetime64[ns] 2013-12-02
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %% [markdown]
# method 参数的选项:
# * None (default): only exact matches
# * pad / ffill: propagate last valid index value forward
# * backfill / bfill: propagate next valid index value backward
# * nearest: use nearest valid index value

# %%
# .sel对整个数据集也可以使用
air_temp.sel(lat=slice(75,50),lon=300,time='2013-12-02T00:00:00')
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 11)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 60.0 57.5 55.0 52.5 50.0
#     lon      float32 300.0
#     time     datetime64[ns] 2013-12-02
# Data variables:
#     air      (lat) float32 253.79999 259.69998 254.39 ... 259.19998 268.79
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [markdown]
# ## 4. 简单绘图

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

air_temp.air.sel(lat=70,lon=250,time='2014').plot()

# %%
air_temp.air.sel(time='2014-12-01T00:00:00').plot()

# %% [markdown]
# ## 5. 基本算术运算

# %%
air_temp + 20.0
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
# Data variables:
#     air      (time, lat, lon) float32 261.2 262.5 263.5 ... 316.49 316.19 315.69
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
air_temp * 1.1
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
# Data variables:
#     air      (time, lat, lon) float32 265.32 266.75 267.85 ... 325.80902 325.259
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
np.sin(air_temp)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 0.6462326 -0.5624663 ... 0.37119254

# %% [markdown]
# # 6. 聚合运算

# %%
air_temp.air.mean(dim='time').plot()

# %%
air_temp.air.mean(dim=['lat','lon']).plot()

# %%
air_temp.air.max(dim='time').plot()

# %%
anomaly = air_temp.air - air_temp.air.mean(dim='time')

# %%
anomaly.sel(time='2014-07-01T00:00:00').plot()

# %%
anomaly.sel(time='2014-12-01T00:00:00').plot()
