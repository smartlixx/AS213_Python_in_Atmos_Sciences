# %% [markdown]
# ## 地图数据处理及可视化

# %% [markdown]
# - 知识点：地理数据读取、处理、坐标系转换及绘图
#
# - 工具：geopandas, descartes, mapclassify, cartopy

# %% [markdown]
# ### 中国每个省级单位有多少个邻居

# %%
import geopandas as gpd

# %%
s = gpd.read_file('../shp_file/china.shp',encoding='utf8')

# %%
s
# Out:
#             AREA  BOUND_A_  BOUND_A_ID    FCNAME                 FENAME  NAME  \
# 0      54.482100         6           5      黑龙江省     Heilongjiang Sheng  None
# 1     129.067000         7           6    内蒙古自治区      Neimongol Zizhiqu  None
# 2     175.086000        23          26  新疆维吾尔自治区  Xinjianguygur Zizhiqu  None
# 3      21.306600        54          59       吉林省            Jilin Sheng  None
# 4      15.589100       107         122       辽宁省         Liaoning Sheng  None
# ...          ...       ...         ...       ...                    ...   ...
# 1362    0.002047      5673        5865       南安礁            Nan an Jiao  None
# 1363    0.002346      5679        5871       南安礁            Nan an Jiao  None
# 1364    0.001124      5786        5985      曾母暗沙           Zengmu Ansha  None
# 1365    0.001574      5793        5992      曾母暗沙           Zengmu Ansha  None
# 1366    0.001854      5795        5994      曾母暗沙           Zengmu Ansha  None
#
#          OWNER   PERIMETER  SOC  \
# 0         黑龙江省   70.132800  CHN
# 1       内蒙古自治区  133.994000  CHN
# 2     新疆维吾尔自治区   86.087100  CHN
# 3          吉林省   43.298200  CHN
# 4          辽宁省   40.620300  CHN
# ...        ...         ...  ...
# 1362       海南省    0.168232  CHN
# 1363       海南省    0.180429  CHN
# 1364       海南省    0.120940  CHN
# 1365       海南省    0.142934  CHN
# 1366       海南省    0.156253  CHN
#
#                                                geometry
# 0     POLYGON ((121.48938 53.33117, 121.49162 53.331...
# 1     POLYGON ((121.48938 53.33117, 121.49769 53.320...
# 2     POLYGON ((87.31262 49.10914, 87.31808 49.10807...
# 3     POLYGON ((123.17773 46.24767, 123.18046 46.248...
# 4     POLYGON ((125.70507 40.86603, 125.69979 40.864...
# ...                                                 ...
# 1362  POLYGON ((112.57276 5.12172, 112.59740 5.12087...
# 1363  POLYGON ((112.92490 5.05133, 112.93376 5.05235...
# 1364  POLYGON ((112.27734 3.97014, 112.28036 3.96595...
# 1365  POLYGON ((112.26261 3.87938, 112.26217 3.87351...
# 1366  POLYGON ((112.05676 3.85817, 112.05611 3.85455...
#
# [1367 rows x 10 columns]

# %%
s.OWNER.unique(),len(s.OWNER.unique())
# Out:
# (array(['黑龙江省', '内蒙古自治区', '新疆维吾尔自治区', '吉林省', '辽宁省', '甘肃省', '河北省', '北京市',
#         '山西省', '天津市', '陕西省', '宁夏回族自治区', '青海省', '山东省', '西藏自治区', '河南省',
#         '江苏省', '安徽省', '四川省', '湖北省', '重庆市', '上海市', '浙江省', '湖南省', '江西省',
#         '云南省', '贵州省', '福建省', '广西壮族自治区', '台湾省', '广东省', '香港特别行政区', '澳门特别行政区',
#         '海南省'], dtype=object),
#  34)

# %%
provinces = s.dissolve(by='OWNER').reset_index()

# %%
provinces = provinces.drop(['AREA','BOUND_A_','BOUND_A_ID','NAME',
                            'SOC','FCNAME','FENAME','PERIMETER'],axis=1)

# %%
for index, row in provinces.iterrows():
    neighbors = provinces[provinces.geometry.touches(row['geometry'])].OWNER.tolist() 
    #neighbors = neighbors.remove(row.OWNER)
    provinces.at[index, "neighbors"] = ", ".join(neighbors)
    provinces.at[index, "neighbors_num"] = len(neighbors)

# %%
provinces.sort_values(by='neighbors_num',ascending=False)
# Out:
#        OWNER                                           geometry  \
# 2     内蒙古自治区  POLYGON ((121.48938 53.33117, 121.49769 53.320...
# 30       陕西省  POLYGON ((111.11640 39.36374, 111.11701 39.363...
# 17       河北省  MULTIPOLYGON (((119.14247 39.30547, 119.14012 ...
# 6        四川省  POLYGON ((105.49535 32.91074, 105.49502 32.905...
# 16       江西省  POLYGON ((118.18945 29.39522, 118.19344 29.386...
# 24       甘肃省  POLYGON ((97.17195 42.79342, 97.18481 42.77167...
# 22       湖南省  POLYGON ((113.94013 29.04828, 113.93997 29.044...
# 9        安徽省  POLYGON ((116.36870 34.64072, 116.37081 34.639...
# 21       湖北省  MULTIPOLYGON (((110.97766 33.25967, 110.98971 ...
# 12       广东省  MULTIPOLYGON (((109.93091 20.22808, 109.93093 ...
# 18       河南省  MULTIPOLYGON (((111.00594 33.17101, 111.00577 ...
# 27       贵州省  MULTIPOLYGON (((109.55247 26.72882, 109.54917 ...
# 29       重庆市  POLYGON ((109.22860 29.12246, 109.22520 29.117...
# 19       浙江省  MULTIPOLYGON (((120.46658 27.16607, 120.46805 ...
# 1        云南省  POLYGON ((105.30025 27.70911, 105.29577 27.698...
# 13   广西壮族自治区  MULTIPOLYGON (((109.21333 20.89708, 109.21089 ...
# 15       江苏省  MULTIPOLYGON (((120.81194 33.01399, 120.81015 ...
# 26     西藏自治区  POLYGON ((89.73125 36.08474, 89.72242 36.08345...
# 11       山西省  POLYGON ((114.12488 40.74365, 114.13085 40.738...
# 10       山东省  MULTIPOLYGON (((120.85508 36.37765, 120.85657 ...
# 31       青海省  POLYGON ((92.40360 39.03967, 92.40493 39.04133...
# 14  新疆维吾尔自治区  POLYGON ((87.31262 49.10914, 87.31808 49.10807...
# 28       辽宁省  MULTIPOLYGON (((121.76275 41.00120, 121.77305 ...
# 8    宁夏回族自治区  MULTIPOLYGON (((106.05062 35.45260, 106.04993 ...
# 5        吉林省  POLYGON ((123.17773 46.24767, 123.18046 46.248...
# 25       福建省  MULTIPOLYGON (((117.41612 23.56332, 117.41653 ...
# 0        上海市  MULTIPOLYGON (((121.42117 30.68613, 121.42240 ...
# 7        天津市  MULTIPOLYGON (((117.69566 39.00026, 117.69897 ...
# 3        北京市  POLYGON ((117.37974 40.22687, 117.38528 40.223...
# 33      黑龙江省  POLYGON ((121.48938 53.33117, 121.49162 53.331...
# 23   澳门特别行政区  MULTIPOLYGON (((113.57883 22.16175, 113.57887 ...
# 32   香港特别行政区  POLYGON ((114.22590 22.54496, 114.22630 22.543...
# 20       海南省  MULTIPOLYGON (((112.05676 3.85817, 112.05611 3...
# 4        台湾省  MULTIPOLYGON (((120.81553 21.75681, 120.81743 ...
#
#                                         neighbors  neighbors_num
# 2     吉林省, 宁夏回族自治区, 山西省, 河北省, 甘肃省, 辽宁省, 陕西省, 黑龙江省            8.0
# 30  内蒙古自治区, 四川省, 宁夏回族自治区, 山西省, 河南省, 湖北省, 甘肃省, 重庆市            8.0
# 17           内蒙古自治区, 北京市, 天津市, 山东省, 山西省, 河南省, 辽宁省            7.0
# 6             云南省, 甘肃省, 西藏自治区, 贵州省, 重庆市, 陕西省, 青海省            7.0
# 16                   安徽省, 广东省, 浙江省, 湖北省, 湖南省, 福建省            6.0
# 24       内蒙古自治区, 四川省, 宁夏回族自治区, 新疆维吾尔自治区, 陕西省, 青海省            6.0
# 22               广东省, 广西壮族自治区, 江西省, 湖北省, 贵州省, 重庆市            6.0
# 9                    山东省, 江苏省, 江西省, 河南省, 浙江省, 湖北省            6.0
# 21                   安徽省, 江西省, 河南省, 湖南省, 重庆市, 陕西省            6.0
# 12       广西壮族自治区, 江西省, 湖南省, 澳门特别行政区, 福建省, 香港特别行政区            6.0
# 18                   安徽省, 山东省, 山西省, 河北省, 湖北省, 陕西省            6.0
# 27                    云南省, 四川省, 广西壮族自治区, 湖南省, 重庆市            5.0
# 29                        四川省, 湖北省, 湖南省, 贵州省, 陕西省            5.0
# 19                        上海市, 安徽省, 江苏省, 江西省, 福建省            5.0
# 1                        四川省, 广西壮族自治区, 西藏自治区, 贵州省            4.0
# 13                             云南省, 广东省, 湖南省, 贵州省            4.0
# 15                             上海市, 安徽省, 山东省, 浙江省            4.0
# 26                        云南省, 四川省, 新疆维吾尔自治区, 青海省            4.0
# 11                          内蒙古自治区, 河北省, 河南省, 陕西省            4.0
# 10                             安徽省, 江苏省, 河北省, 河南省            4.0
# 31                      四川省, 新疆维吾尔自治区, 甘肃省, 西藏自治区            4.0
# 14                                甘肃省, 西藏自治区, 青海省            3.0
# 28                               内蒙古自治区, 吉林省, 河北省            3.0
# 8                                内蒙古自治区, 甘肃省, 陕西省            3.0
# 5                               内蒙古自治区, 辽宁省, 黑龙江省            3.0
# 25                                  广东省, 江西省, 浙江省            3.0
# 0                                        江苏省, 浙江省            2.0
# 7                                        北京市, 河北省            2.0
# 3                                        天津市, 河北省            2.0
# 33                                    内蒙古自治区, 吉林省            2.0
# 23                                            广东省            1.0
# 32                                            广东省            1.0
# 20                                                           0.0
# 4                                                            0.0

# %% [markdown]
# 大家可以将这个结果和 https://www.sohu.com/a/355921579_353978 对照一下，看看结果是否正确。

# %% [markdown]
# ### 地图标注、填色

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

#crs = ccrs.LambertConformal(central_longitude=105.) #AzimuthalEqualArea()
crs = ccrs.LambertAzimuthalEqualArea(central_longitude=105.)

fig,ax = plt.subplots(figsize=(10,8),subplot_kw={'projection': crs})
provinces.plot(ax=ax, facecolor='grey', edgecolor='white', linestyle='--', alpha=0.8, transform=ccrs.PlateCarree())
#ax.background_patch.set_visible(False)
ax.outline_patch.set_visible(False)
#ax.axis('off')
ax.set_extent([75,130,15,54])
provinces.geometry.representative_point().plot(ax=ax, facecolor='white', edgecolor='black', 
                                               marker='*', markersize=100, linewidth=0.5,
                                               transform=ccrs.Geodetic())

# %%
def shorten_prov_names(prov_name:str) -> str:   # Type hint, valid for python version >= 3.5
    if ('自' in prov_name or '特' in prov_name) and prov_name != '内蒙古自治区':
        name = prov_name[:2]
    else:
        name = prov_name.replace('省', '').replace('市', '').replace('自治区', '')
    return name

# %%
import matplotlib as mpl
# 请使用你的电脑上的字体文件
myfont = mpl.font_manager.FontProperties(fname='/System/Library/Fonts/STHeiti Light.ttc')

fig,ax = plt.subplots(figsize=(10,8),subplot_kw={'projection': crs})
provinces.plot(ax=ax, facecolor='grey', edgecolor='white', linestyle='--', alpha=0.8, transform=ccrs.PlateCarree())
#ax.background_patch.set_visible(False)
ax.outline_patch.set_visible(False)
#ax.axis('off')
ax.set_extent([75,130,15,54])

for index, row in provinces.iterrows():
    region = shorten_prov_names(row['OWNER'])

    ax.text(row.geometry.representative_point().x, row.geometry.representative_point().y,
            region, ha="center", va="center", size=6, transform=ccrs.Geodetic(),
            fontproperties=myfont)

# %% [markdown]
# 我们来获取 COVID-19 确诊信息，并把每个省的累计确诊数据画到地图上。
#
# 腾讯提供了实时疫情信息，我们可以从该网页分析出其输出数据的实际网址和参数（利用 Chrome 或者 Firefox 的开发者工具）。

# %%
import requests, json

url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5'

req = requests.get(url)

# %%
data = req.json()

# %%
data.keys()
# Out:
# dict_keys(['ret', 'data'])

# %%
data['data']
# Out:
# '{"lastUpdateTime":"2020-04-19 21:57:28","chinaTotal":{"confirm":84225,"heal":77876,"dead":4642,"nowConfirm":1707,"suspect":48,"nowSevere":85,"importedCase":1575,"noInfect":999},"chinaAdd":{"confirm":43,"heal":132,"dead":0,"nowConfirm":-87,"suspect":-15,"nowSevere":0,"importedCase":9,"noInfect":44},"isShowAdd":true,"showAddSwitch":{"all":true,"confirm":true,"suspect":true,"dead":true,"heal":true,"nowConfirm":true,"nowSevere":true,"importedCase":true,"noInfect":true},"areaTree":[{"name":"中国","today":{"confirm":43,"isUpdated":true},"total":{"nowConfirm":1707,"confirm":84225,"suspect":48,"dead":4642,"deadRate":"5.51","showRate":false,"heal":77876,"healRate":"92.46","showHeal":true},"children":[{"name":"香港","today":{"confirm":2,"confirmCuts":0,"isUpdated":true,"tip":""},"total":{"nowConfirm":419,"confirm":1025,"suspect":0,"dead":4,"deadRate":"0.39","showRate":false,"heal":602,"healRate":"58.73","showHeal":true},"children":[{"name":"地区待确认","today":{"confirm":2,"confirmCuts":0,"isUpdated":true},"total":{"nowConfirm":419,"confirm":1025,"suspect":0,"dead":4,"deadRate":"0.39","showRate":false,"heal":602,"healRate":"58.73","showHeal":true}}]},{"name":"黑龙江","today":{"confirm":6,"confirmCuts":0,"isUpdated":true,"tip":"黑龙江省累计报告境外输入确诊病例377例。"},"total":{"nowConfirm":413,"confirm":898,"suspect":0,"dead":13,"deadRate":"1.45","showRate":false,"heal":472,"healRate":"52.56","showHeal":true},"children":[{"name":"境外输入","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":375,"confirm":377,"suspect":0,"dead":0,"deadRate":"0.00","showRate":false,"heal":2,"healRate":"0.53","showHeal":true}},{"name":"哈尔滨","today":{"confirm":4,"confirmCuts":0,"isUpdated":true},"total":{"nowConfirm":36,"confirm":235,"suspect":0,"dead":4,"deadRate":"1.70","showRate":false,"heal":195,"healRate":"82.98","showHeal":true}},{"name":"牡丹江","today":{"confirm":2,"confirmCuts":0,"isUpdated":true},"total":{"nowConfirm":2,"confirm":17,"suspect":0,"dead":0,"deadRate":"0.00","showRate":false,"heal":15,"healRate":"88.24","showHeal":true}},{"name":"双鸭山","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":0,"confirm":52,"suspect":0,"dead":3,"deadRate":"5.77","showRate":false,"heal":49,"healRate":"94.23","showHeal":true}},{"name":"大兴安岭","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":0,"confirm":3,"suspect":0,"dead":0,"deadRate":"0.00","showRate":false,"heal":3,"healRate":"100.00","showHeal":true}},{"name":"黑河","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":0,"confirm":14,"suspect":0,"dead":0,"deadRate":"0.00","showRate":false,"heal":14,"healRate":"100.00","showHeal":true}},{"name":"大庆","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":0,"confirm":26,"suspect":0,"dead":1,"deadRate":"3.85","showRate":false,"heal":25,"healRate":"96.15","showHeal":true}},{"name":"齐齐哈尔","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":0,"confirm":43,"suspect":0,"dead":1,"deadRate":"2.33","showRate":false,"heal":42,"healRate":"97.67","showHeal":true}},{"name":"绥化","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":0,"confirm":47,"suspect":0,"dead":4,"deadRate":"8.51","showRate":false,"heal":43,"healRate":"91.49","showHeal":true}},{"name":"鹤岗","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":0,"confirm":5,"suspect":0,"dead":0,"deadRate":"0.00","showRate":false,"heal":5,"healRate":"100.00","showHeal":true}},{"name":"七台河","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":0,"confirm":17,"suspect":0,"dead":0,"deadRate":"0.00","showRate":false,"heal":17,"healRate":"100.00","showHeal":true}},{"name":"鸡西","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"total":{"nowConfirm":0,"confirm":46,"suspect":0,"dead":0,"deadRate":"0.00","showRate":false,"heal":46,"healRate":"100.00","showHeal":true}},{"name":"伊春","today":{"confirm":0,"confirmCuts":0,"isUpdated":false},"tot ...

# %%
china_data = json.loads(data['data'])

china_data.keys()
# Out:
# dict_keys(['lastUpdateTime', 'chinaTotal', 'chinaAdd', 'isShowAdd', 'showAddSwitch', 'areaTree'])

# %%
china_data['areaTree']
# Out:
# [{'name': '中国',
#   'today': {'confirm': 43, 'isUpdated': True},
#   'total': {'nowConfirm': 1707,
#    'confirm': 84225,
#    'suspect': 48,
#    'dead': 4642,
#    'deadRate': '5.51',
#    'showRate': False,
#    'heal': 77876,
#    'healRate': '92.46',
#    'showHeal': True},
#   'children': [{'name': '香港',
#     'today': {'confirm': 2, 'confirmCuts': 0, 'isUpdated': True, 'tip': ''},
#     'total': {'nowConfirm': 419,
#      'confirm': 1025,
#      'suspect': 0,
#      'dead': 4,
#      'deadRate': '0.39',
#      'showRate': False,
#      'heal': 602,
#      'healRate': '58.73',
#      'showHeal': True},
#     'children': [{'name': '地区待确认',
#       'today': {'confirm': 2, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 419,
#        'confirm': 1025,
#        'suspect': 0,
#        'dead': 4,
#        'deadRate': '0.39',
#        'showRate': False,
#        'heal': 602,
#        'healRate': '58.73',
#        'showHeal': True}}]},
#    {'name': '黑龙江',
#     'today': {'confirm': 6,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '黑龙江省累计报告境外输入确诊病例377例。'},
#     'total': {'nowConfirm': 413,
#      'confirm': 898,
#      'suspect': 0,
#      'dead': 13,
#      'deadRate': '1.45',
#      'showRate': False,
#      'heal': 472,
#      'healRate': '52.56',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 375,
#        'confirm': 377,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 2,
#        'healRate': '0.53',
#        'showHeal': True}},
#      {'name': '哈尔滨',
#       'today': {'confirm': 4, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 36,
#        'confirm': 235,
#        'suspect': 0,
#        'dead': 4,
#        'deadRate': '1.70',
#        'showRate': False,
#        'heal': 195,
#        'healRate': '82.98',
#        'showHeal': True}},
#      {'name': '牡丹江',
#       'today': {'confirm': 2, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 2,
#        'confirm': 17,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 15,
#        'healRate': '88.24',
#        'showHeal': True}},
#      {'name': '双鸭山',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 52,
#        'suspect': 0,
#        'dead': 3,
#        'deadRate': '5.77',
#        'showRate': False,
#        'heal': 49,
#        'healRate': '94.23',
#        'showHeal': True}},
#      {'name': '大兴安岭',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 3,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '黑河',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 14,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 14,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '大庆',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 26,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '3.85',
#        'showRate': False,
#        'heal': 25,
#        'healRate': '96.15',
#        'showHeal': True}},
#      {'name': '齐齐哈尔',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 43,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '2.33',
#        'showRate': False,
#        'heal': 42,
#        'healRate': '97.67',
#        'showHeal': True}},
#      {'name': '绥化',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 47,
#        'suspect': 0,
#        'dead': 4,
#        'deadRate': '8.51',
#        'showRate': False,
#        'heal': 43,
#        'healRate': '91.49',
#        'showHeal': True}},
#      {'name': '鹤岗',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 5,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 5,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '七台河',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 17,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 17,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '鸡西',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 46,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 46,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '伊春',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 1,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 1,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '佳木斯',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 15,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 15,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '台湾',
#     'today': {'confirm': 25, 'confirmCuts': 0, 'isUpdated': True, 'tip': ''},
#     'total': {'nowConfirm': 225,
#      'confirm': 420,
#      'suspect': 0,
#      'dead': 6,
#      'deadRate': '1.43',
#      'showRate': False,
#      'heal': 189,
#      'healRate': '45.00',
#      'showHeal': True},
#     'children': [{'name': '地区待确认',
#       'today': {'confirm': 25, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 225,
#        'confirm': 420,
#        'suspect': 0,
#        'dead': 6,
#        'deadRate': '1.43',
#        'showRate': False,
#        'heal': 189,
#        'healRate': '45.00',
#        'showHeal': True}}]},
#    {'name': '湖北',
#     'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True, 'tip': ''},
#     'total': {'nowConfirm': 109,
#      'confirm': 68128,
#      'suspect': 0,
#      'dead': 4512,
#      'deadRate': '6.62',
#      'showRate': False,
#      'heal': 63507,
#      'healRate': '93.22',
#      'showHeal': True},
#     'children': [{'name': '武汉',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 109,
#        'confirm': 50333,
#        'suspect': 0,
#        'dead': 3869,
#        'deadRate': '7.69',
#        'showRate': False,
#        'heal': 46355,
#        'healRate': '92.10',
#        'showHeal': True}},
#      {'name': '十堰',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 672,
#        'suspect': 0,
#        'dead': 8,
#        'deadRate': '1.19',
#        'showRate': False,
#        'heal': 664,
#        'healRate': '98.81',
#        'showHeal': True}},
#      {'name': '潜江',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 198,
#        'suspect': 0,
#        'dead': 9,
#        'deadRate': '4.55',
#        'showRate': False,
#        'heal': 189,
#        'healRate': '95.45',
#        'showHeal': True}},
#      {'name': '鄂州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 1394,
#        'suspect': 0,
#        'dead': 59,
#        'deadRate': '4.23',
#        'showRate': False,
#        'heal': 1335,
#        'healRate': '95.77',
#        'showHeal': True}},
#      {'name': '天门',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 496,
#        'suspect': 0,
#        'dead': 15,
#        'deadRate': '3.02',
#        'showRate': False,
#        'heal': 481,
#        'healRate': '96.98',
#        'showHeal': True}},
#      {'name': '襄阳',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 1175,
#        'suspect': 0,
#        'dead': 40,
#        'deadRate': '3.40',
#        'showRate': False,
#        'heal': 1135,
#        'healRate': '96.60',
#        'showHeal': True}},
#      {'name': '仙桃',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 575,
#        'suspect': 0,
#        'dead': 22,
#        'deadRate': '3.83',
#        'showRate': False,
#        'heal': 553,
#        'healRate': '96.17',
#        'showHeal': True}},
#      {'name': '恩施州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 252,
#        'suspect': 0,
#        'dead': 7,
#        'deadRate': '2.78',
#        'showRate': False,
#        'heal': 245,
#        'healRate': '97.22',
#        'showHeal': True}},
#      {'name': '神农架',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 11,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 11,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '宜昌',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 931,
#        'suspect': 0,
#        'dead': 37,
#        'deadRate': '3.97',
#        'showRate': False,
#        'heal': 894,
#        'healRate': '96.03',
#        'showHeal': True}},
#      {'name': '黄石',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 1015,
#        'suspect': 0,
#        'dead': 39,
#        'deadRate': '3.84',
#        'showRate': False,
#        'heal': 976,
#        'healRate': '96.16',
#        'showHeal': True}},
#      {'name': '荆州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 1580,
#        'suspect': 0,
#        'dead': 52,
#        'deadRate': '3.29',
#        'showRate': False,
#        'heal': 1528,
#        'healRate': '96.71',
#        'showHeal': True}},
#      {'name': '随州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 1307,
#        'suspect': 0,
#        'dead': 45,
#        'deadRate': '3.44',
#        'showRate': False,
#        'heal': 1262,
#        'healRate': '96.56',
#        'showHeal': True}},
#      {'name': '荆门',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 928,
#        'suspect': 0,
#        'dead': 41,
#        'deadRate': '4.42',
#        'showRate': False,
#        'heal': 887,
#        'healRate': '95.58',
#        'showHeal': True}},
#      {'name': '咸宁',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 836,
#        'suspect': 0,
#        'dead': 15,
#        'deadRate': '1.79',
#        'showRate': False,
#        'heal': 821,
#        'healRate': '98.21',
#        'showHeal': True}},
#      {'name': '黄冈',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 2907,
#        'suspect': 0,
#        'dead': 125,
#        'deadRate': '4.30',
#        'showRate': False,
#        'heal': 2782,
#        'healRate': '95.70',
#        'showHeal': True}},
#      {'name': '孝感',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 3518,
#        'suspect': 0,
#        'dead': 129,
#        'deadRate': '3.67',
#        'showRate': False,
#        'heal': 3389,
#        'healRate': '96.33',
#        'showHeal': True}}]},
#    {'name': '上海',
#     'today': {'confirm': 7,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '上海累计报告境外输入确诊病例296例。'},
#     'total': {'nowConfirm': 107,
#      'confirm': 635,
#      'suspect': 0,
#      'dead': 7,
#      'deadRate': '1.10',
#      'showRate': False,
#      'heal': 521,
#      'healRate': '82.05',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 7, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 106,
#        'confirm': 296,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 190,
#        'healRate': '64.19',
#        'showHeal': True}},
#      {'name': '外地来沪',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 1,
#        'confirm': 111,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '0.90',
#        'showRate': False,
#        'heal': 109,
#        'healRate': '98.20',
#        'showHeal': True}},
#      {'name': '青浦',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 6,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 6,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '地区待确认',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 0,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': True}},
#      {'name': '嘉定',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 9,
#        'suspect': 0,
#        'dead': 2,
#        'deadRate': '22.22',
#        'showRate': False,
#        'heal': 7,
#        'healRate': '77.78',
#        'showHeal': True}},
#      {'name': '徐汇',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 18,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '5.56',
#        'showRate': False,
#        'heal': 17,
#        'healRate': '94.44',
#        'showHeal': True}},
#      {'name': '静安',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 16,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '6.25',
#        'showRate': False,
#        'heal': 15,
#        'healRate': '93.75',
#        'showHeal': True}},
#      {'name': '黄浦',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 6,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '16.67',
#        'showRate': False,
#        'heal': 5,
#        'healRate': '83.33',
#        'showHeal': True}},
#      {'name': '浦东',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 61,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 61,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '宝山',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 22,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '4.55',
#        'showRate': False,
#        'heal': 21,
#        'healRate': '95.45',
#        'showHeal': True}},
#      {'name': '崇明',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 4,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 4,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '金山',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 4,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 4,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '虹口',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 7,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 7,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '奉贤',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 9,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 9,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '杨浦',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 9,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 9,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '普陀',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 11,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 11,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '长宁',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 13,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 13,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '松江',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 14,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 14,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '闵行',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 19,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 19,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '内蒙古',
#     'today': {'confirm': 0,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '内蒙古自治区累计报告境外输入确诊病例118例。'},
#     'total': {'nowConfirm': 88,
#      'confirm': 193,
#      'suspect': 0,
#      'dead': 1,
#      'deadRate': '0.52',
#      'showRate': False,
#      'heal': 104,
#      'healRate': '53.89',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 88,
#        'confirm': 118,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 30,
#        'healRate': '25.42',
#        'showHeal': True}},
#      {'name': '包头',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 11,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 11,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '呼和浩特',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 7,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 7,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '乌兰察布',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 3,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '锡林郭勒',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 9,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 9,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '赤峰',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 9,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 9,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '通辽',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 7,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 7,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '鄂尔多斯',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 11,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 11,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '呼伦贝尔',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 7,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 7,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '巴彦淖尔',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 8,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '12.50',
#        'showRate': False,
#        'heal': 7,
#        'healRate': '87.50',
#        'showHeal': True}},
#      {'name': '兴安盟',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 1,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 1,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '乌海',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 2,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 2,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '广东',
#     'today': {'confirm': 1,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '广东省累计报告境外输入病例190例。'},
#     'total': {'nowConfirm': 82,
#      'confirm': 1580,
#      'suspect': 0,
#      'dead': 8,
#      'deadRate': '0.51',
#      'showRate': False,
#      'heal': 1490,
#      'healRate': '94.30',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 49,
#        'confirm': 190,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 141,
#        'healRate': '74.21',
#        'showHeal': True}},
#      {'name': '广州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 23,
#        'confirm': 375,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '0.27',
#        'showRate': False,
#        'heal': 351,
#        'healRate': '93.60',
#        'showHeal': True}},
#      {'name': '深圳',
#       'today': {'confirm': 1, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 4,
#        'confirm': 422,
#        'suspect': 0,
#        'dead': 3,
#        'deadRate': '0.71',
#        'showRate': False,
#        'heal': 415,
#        'healRate': '98.34',
#        'showHeal': True}},
#      {'name': '佛山',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 2,
#        'confirm': 87,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 85,
#        'healRate': '97.70',
#        'showHeal': True}},
#      {'name': '揭阳',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 2,
#        'confirm': 10,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 8,
#        'healRate': '80.00',
#        'showHeal': True}},
#      {'name': '中山',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 1,
#        'confirm': 67,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 66,
#        'healRate': '98.51',
#        'showHeal': True}},
#      {'name': '河源',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 1,
#        'confirm': 5,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 4,
#        'healRate': '80.00',
#        'showHeal': True}},
#      {'name': '汕尾',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 5,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 5,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '肇庆',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 19,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '5.26',
#        'showRate': False,
#        'heal': 18,
#        'healRate': '94.74',
#        'showHeal': True}},
#      {'name': '地区待确认',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 0,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': True}},
#      {'name': '东莞',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 99,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '1.01',
#        'showRate': False,
#        'heal': 98,
#        'healRate': '98.99',
#        'showHeal': True}},
#      {'name': '阳江',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 14,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 14,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '清远',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 12,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 12,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '潮州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 5,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 5,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '湛江',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 22,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 22,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '珠海',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 98,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '1.02',
#        'showRate': False,
#        'heal': 97,
#        'healRate': '98.98',
#        'showHeal': True}},
#      {'name': '汕头',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 25,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 25,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '惠州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 62,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 62,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '江门',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 23,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 23,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '茂名',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 14,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 14,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '韶关',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 10,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '10.00',
#        'showRate': False,
#        'heal': 9,
#        'healRate': '90.00',
#        'showHeal': True}},
#      {'name': '梅州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 16,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 16,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '北京',
#     'today': {'confirm': 0,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '北京累计报告境外输入确诊病例174例。\n北京卫健委未明确治愈病例和死亡病例的归属分区，北京分区现有确诊数据暂无法获取。'},
#     'total': {'nowConfirm': 75,
#      'confirm': 593,
#      'suspect': 0,
#      'dead': 8,
#      'deadRate': '1.35',
#      'showRate': False,
#      'heal': 510,
#      'healRate': '86.00',
#      'showHeal': True},
#     'children': [{'name': '朝阳',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 75,
#        'confirm': 75,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 68,
#        'confirm': 174,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 106,
#        'healRate': '60.92',
#        'showHeal': True}},
#      {'name': '海淀',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 64,
#        'confirm': 64,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '西城',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 53,
#        'confirm': 53,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '丰台',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 43,
#        'confirm': 43,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '大兴',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 39,
#        'confirm': 39,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '昌平',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 29,
#        'confirm': 29,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '外地来京',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 25,
#        'confirm': 25,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '通州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 19,
#        'confirm': 19,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '房山',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 16,
#        'confirm': 16,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '东城',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 14,
#        'confirm': 14,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '石景山',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 14,
#        'confirm': 14,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '顺义',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 10,
#        'confirm': 10,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '密云',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 7,
#        'confirm': 7,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '怀柔',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 7,
#        'confirm': 7,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '门头沟',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 3,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '延庆',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 1,
#        'confirm': 1,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': False}},
#      {'name': '地区待确认',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': -412,
#        'confirm': 0,
#        'suspect': 0,
#        'dead': 8,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 404,
#        'healRate': '0.00',
#        'showHeal': True}}]},
#    {'name': '山西',
#     'today': {'confirm': 0,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '山西省累计报告境外输入确诊病例64例。'},
#     'total': {'nowConfirm': 62,
#      'confirm': 197,
#      'suspect': 0,
#      'dead': 0,
#      'deadRate': '0.00',
#      'showRate': False,
#      'heal': 135,
#      'healRate': '68.53',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 62,
#        'confirm': 64,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 2,
#        'healRate': '3.12',
#        'showHeal': True}},
#      {'name': '晋中',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 37,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 37,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '大同',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 12,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 12,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '运城',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 19,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 19,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '忻州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 7,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 7,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '晋城',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 10,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 10,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '长治',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 8,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 8,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '太原',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 20,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 20,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '朔州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 8,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 8,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '临汾',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 2,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 2,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '阳泉',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 4,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 4,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '吕梁',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 6,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 6,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '澳门',
#     'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True, 'tip': ''},
#     'total': {'nowConfirm': 28,
#      'confirm': 45,
#      'suspect': 0,
#      'dead': 0,
#      'deadRate': '0.00',
#      'showRate': False,
#      'heal': 17,
#      'healRate': '37.78',
#      'showHeal': True},
#     'children': [{'name': '地区待确认',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 28,
#        'confirm': 45,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 17,
#        'healRate': '37.78',
#        'showHeal': True}}]},
#    {'name': '浙江',
#     'today': {'confirm': 0,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '浙江累计报告境外输入确诊病例50例。'},
#     'total': {'nowConfirm': 20,
#      'confirm': 1268,
#      'suspect': 0,
#      'dead': 1,
#      'deadRate': '0.08',
#      'showRate': False,
#      'heal': 1247,
#      'healRate': '98.34',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 20,
#        'confirm': 50,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 30,
#        'healRate': '60.00',
#        'showHeal': True}},
#      {'name': '金华',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 55,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 55,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '省十里丰监狱',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 36,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 36,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '丽水',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 17,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 17,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '台州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 146,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 146,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '舟山',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 10,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 10,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '衢州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 14,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 14,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '绍兴',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 42,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 42,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '嘉兴',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 46,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 46,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '湖州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 10,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 10,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '温州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 504,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '0.20',
#        'showRate': False,
#        'heal': 503,
#        'healRate': '99.80',
#        'showHeal': True}},
#      {'name': '宁波',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 157,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 157,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '杭州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True},
#       'total': {'nowConfirm': 0,
#        'confirm': 181,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 181,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '山东',
#     'today': {'confirm': 0,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '山东累计报告境外输入确诊病例24例。'},
#     'total': {'nowConfirm': 15,
#      'confirm': 787,
#      'suspect': 0,
#      'dead': 7,
#      'deadRate': '0.89',
#      'showRate': False,
#      'heal': 765,
#      'healRate': '97.20',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 11,
#        'confirm': 24,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 13,
#        'healRate': '54.17',
#        'showHeal': True}},
#      {'name': '青岛',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 4,
#        'confirm': 65,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '1.54',
#        'showRate': False,
#        'heal': 60,
#        'healRate': '92.31',
#        'showHeal': True}},
#      {'name': '泰安',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 35,
#        'suspect': 0,
#        'dead': 2,
#        'deadRate': '5.71',
#        'showRate': False,
#        'heal': 33,
#        'healRate': '94.29',
#        'showHeal': True}},
#      {'name': '济南',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 47,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 47,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '烟台',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 47,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 47,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '淄博',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 30,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '3.33',
#        'showRate': False,
#        'heal': 29,
#        'healRate': '96.67',
#        'showHeal': True}},
#      {'name': '枣庄',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 24,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 24,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '潍坊',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 44,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 44,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '济宁',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 260,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 260,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '威海',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 38,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '2.63',
#        'showRate': False,
#        'heal': 37,
#        'healRate': '97.37',
#        'showHeal': True}},
#      {'name': '日照',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
# ...
#        'healRate': '93.33',
#        'showHeal': True}},
#      {'name': '三亚',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 54,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '1.85',
#        'showRate': False,
#        'heal': 53,
#        'healRate': '98.15',
#        'showHeal': True}},
#      {'name': '东方',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '33.33',
#        'showRate': False,
#        'heal': 2,
#        'healRate': '66.67',
#        'showHeal': True}},
#      {'name': '万宁',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 13,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 13,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '澄迈县',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 9,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '11.11',
#        'showRate': False,
#        'heal': 8,
#        'healRate': '88.89',
#        'showHeal': True}},
#      {'name': '昌江县',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 7,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 7,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '保亭',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 3,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '琼海',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 6,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '16.67',
#        'showRate': False,
#        'heal': 5,
#        'healRate': '83.33',
#        'showHeal': True}},
#      {'name': '临高县',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 6,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 6,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '陵水县',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 4,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 4,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '乐东',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 2,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 2,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '文昌',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 3,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '定安县',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '33.33',
#        'showRate': False,
#        'heal': 2,
#        'healRate': '66.67',
#        'showHeal': True}},
#      {'name': '琼中县',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 1,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 1,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '江西',
#     'today': {'confirm': 0,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '江西累计报告境外输入病例2例。'},
#     'total': {'nowConfirm': 0,
#      'confirm': 937,
#      'suspect': 0,
#      'dead': 1,
#      'deadRate': '0.11',
#      'showRate': False,
#      'heal': 936,
#      'healRate': '99.89',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 2,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 2,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '九江',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 118,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 118,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '南昌',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 230,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 230,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '上饶',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 123,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 123,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '新余',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 130,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 130,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '抚州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 72,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 72,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '吉安',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 22,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 22,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '赣州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 76,
#        'suspect': 0,
#        'dead': 1,
#        'deadRate': '1.32',
#        'showRate': False,
#        'heal': 75,
#        'healRate': '98.68',
#        'showHeal': True}},
#      {'name': '萍乡',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 33,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 33,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '宜春',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 106,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 106,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '鹰潭',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 18,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 18,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '景德镇',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 6,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 6,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '赣江新区',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 1,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 1,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '宁夏',
#     'today': {'confirm': 0,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '宁夏累计确诊病例中包含3名境外输入型病例。'},
#     'total': {'nowConfirm': 0,
#      'confirm': 75,
#      'suspect': 0,
#      'dead': 0,
#      'deadRate': '0.00',
#      'showRate': False,
#      'heal': 75,
#      'healRate': '100.00',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 3,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '银川',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 34,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 34,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '吴忠',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 28,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 28,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '固原',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 5,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 5,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '中卫',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 3,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '石嘴山',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 1,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 1,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '宁东管委会',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 1,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 1,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '甘肃',
#     'today': {'confirm': 0,
#      'confirmCuts': 0,
#      'isUpdated': True,
#      'tip': '甘肃累计报告境外输入确诊病例47例。'},
#     'total': {'nowConfirm': 0,
#      'confirm': 139,
#      'suspect': 0,
#      'dead': 2,
#      'deadRate': '1.44',
#      'showRate': False,
#      'heal': 137,
#      'healRate': '98.56',
#      'showHeal': True},
#     'children': [{'name': '境外输入',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 47,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 47,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '兰州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 37,
#        'suspect': 0,
#        'dead': 2,
#        'deadRate': '5.41',
#        'showRate': False,
#        'heal': 35,
#        'healRate': '94.59',
#        'showHeal': True}},
#      {'name': '定西',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 9,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 9,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '地区待确认',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 0,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 0,
#        'healRate': '0.00',
#        'showHeal': True}},
#      {'name': '平凉',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 9,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 9,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '庆阳',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 3,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '白银',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 4,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 4,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '甘南州',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 8,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 8,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '天水',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 12,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 12,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '陇南',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 4,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 4,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '临夏',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 3,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 3,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '张掖',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 2,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 2,
#        'healRate': '100.00',
#        'showHeal': True}},
#      {'name': '金昌',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 1,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 1,
#        'healRate': '100.00',
#        'showHeal': True}}]},
#    {'name': '西藏',
#     'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': True, 'tip': ''},
#     'total': {'nowConfirm': 0,
#      'confirm': 1,
#      'suspect': 0,
#      'dead': 0,
#      'deadRate': '0.00',
#      'showRate': False,
#      'heal': 1,
#      'healRate': '100.00',
#      'showHeal': True},
#     'children': [{'name': '拉萨',
#       'today': {'confirm': 0, 'confirmCuts': 0, 'isUpdated': False},
#       'total': {'nowConfirm': 0,
#        'confirm': 1,
#        'suspect': 0,
#        'dead': 0,
#        'deadRate': '0.00',
#        'showRate': False,
#        'heal': 1,
#        'healRate': '100.00',
#        'showHeal': True}}]}]}]

# %%
china_data['areaTree'][0].keys()
# Out:
# dict_keys(['name', 'today', 'total', 'children'])

# %%
for item in china_data['areaTree'][0].get('children'):
    print(item['name'],': ', item['total']['confirm'])
# Out:
# 香港 :  1025
# 黑龙江 :  898
# 台湾 :  420
# 湖北 :  68128
# 上海 :  635
# 内蒙古 :  193
# 广东 :  1580
# 北京 :  593
# 山西 :  197
# 澳门 :  45
# 浙江 :  1268
# 山东 :  787
# 福建 :  355
# 天津 :  189
# 江苏 :  653
# 吉林 :  104
# 河北 :  328
# 四川 :  561
# 云南 :  184
# 重庆 :  579
# 辽宁 :  146
# 陕西 :  256
# 安徽 :  991
# 新疆 :  76
# 广西 :  254
# 贵州 :  147
# 青海 :  18
# 湖南 :  1019
# 河南 :  1276
# 海南 :  168
# 江西 :  937
# 宁夏 :  75
# 甘肃 :  139
# 西藏 :  1

# %%
prov_confirm = dict()

prov_confirm = {item['name']: int(item['total']['confirm'])
                    for item in china_data['areaTree'][0].get('children')}

# %%
prov_confirm
# Out:
# {'香港': 1025,
#  '黑龙江': 898,
#  '台湾': 420,
#  '湖北': 68128,
#  '上海': 635,
#  '内蒙古': 193,
#  '广东': 1580,
#  '北京': 593,
#  '山西': 197,
#  '澳门': 45,
#  '浙江': 1268,
#  '山东': 787,
#  '福建': 355,
#  '天津': 189,
#  '江苏': 653,
#  '吉林': 104,
#  '河北': 328,
#  '四川': 561,
#  '云南': 184,
#  '重庆': 579,
#  '辽宁': 146,
#  '陕西': 256,
#  '安徽': 991,
#  '新疆': 76,
#  '广西': 254,
#  '贵州': 147,
#  '青海': 18,
#  '湖南': 1019,
#  '河南': 1276,
#  '海南': 168,
#  '江西': 937,
#  '宁夏': 75,
#  '甘肃': 139,
#  '西藏': 1}

# %%
provinces['OWNER'] = provinces['OWNER'].map(shorten_prov_names)

# %%
provinces
# Out:
#    OWNER                                           geometry  \
# 0     上海  MULTIPOLYGON (((121.42117 30.68613, 121.42240 ...
# 1     云南  POLYGON ((105.30025 27.70911, 105.29577 27.698...
# 2    内蒙古  POLYGON ((121.48938 53.33117, 121.49769 53.320...
# 3     北京  POLYGON ((117.37974 40.22687, 117.38528 40.223...
# 4     台湾  MULTIPOLYGON (((120.81553 21.75681, 120.81743 ...
# 5     吉林  POLYGON ((123.17773 46.24767, 123.18046 46.248...
# 6     四川  POLYGON ((105.49535 32.91074, 105.49502 32.905...
# 7     天津  MULTIPOLYGON (((117.69566 39.00026, 117.69897 ...
# 8     宁夏  MULTIPOLYGON (((106.05062 35.45260, 106.04993 ...
# 9     安徽  POLYGON ((116.36870 34.64072, 116.37081 34.639...
# 10    山东  MULTIPOLYGON (((120.85508 36.37765, 120.85657 ...
# 11    山西  POLYGON ((114.12488 40.74365, 114.13085 40.738...
# 12    广东  MULTIPOLYGON (((109.93091 20.22808, 109.93093 ...
# 13    广西  MULTIPOLYGON (((109.21333 20.89708, 109.21089 ...
# 14    新疆  POLYGON ((87.31262 49.10914, 87.31808 49.10807...
# 15    江苏  MULTIPOLYGON (((120.81194 33.01399, 120.81015 ...
# 16    江西  POLYGON ((118.18945 29.39522, 118.19344 29.386...
# 17    河北  MULTIPOLYGON (((119.14247 39.30547, 119.14012 ...
# 18    河南  MULTIPOLYGON (((111.00594 33.17101, 111.00577 ...
# 19    浙江  MULTIPOLYGON (((120.46658 27.16607, 120.46805 ...
# 20    海南  MULTIPOLYGON (((112.05676 3.85817, 112.05611 3...
# 21    湖北  MULTIPOLYGON (((110.97766 33.25967, 110.98971 ...
# 22    湖南  POLYGON ((113.94013 29.04828, 113.93997 29.044...
# 23    澳门  MULTIPOLYGON (((113.57883 22.16175, 113.57887 ...
# 24    甘肃  POLYGON ((97.17195 42.79342, 97.18481 42.77167...
# 25    福建  MULTIPOLYGON (((117.41612 23.56332, 117.41653 ...
# 26    西藏  POLYGON ((89.73125 36.08474, 89.72242 36.08345...
# 27    贵州  MULTIPOLYGON (((109.55247 26.72882, 109.54917 ...
# 28    辽宁  MULTIPOLYGON (((121.76275 41.00120, 121.77305 ...
# 29    重庆  POLYGON ((109.22860 29.12246, 109.22520 29.117...
# 30    陕西  POLYGON ((111.11640 39.36374, 111.11701 39.363...
# 31    青海  POLYGON ((92.40360 39.03967, 92.40493 39.04133...
# 32    香港  POLYGON ((114.22590 22.54496, 114.22630 22.543...
# 33   黑龙江  POLYGON ((121.48938 53.33117, 121.49162 53.331...
#
#                                         neighbors  neighbors_num
# 0                                        江苏省, 浙江省            2.0
# 1                        四川省, 广西壮族自治区, 西藏自治区, 贵州省            4.0
# 2     吉林省, 宁夏回族自治区, 山西省, 河北省, 甘肃省, 辽宁省, 陕西省, 黑龙江省            8.0
# 3                                        天津市, 河北省            2.0
# 4                                                            0.0
# 5                               内蒙古自治区, 辽宁省, 黑龙江省            3.0
# 6             云南省, 甘肃省, 西藏自治区, 贵州省, 重庆市, 陕西省, 青海省            7.0
# 7                                        北京市, 河北省            2.0
# 8                                内蒙古自治区, 甘肃省, 陕西省            3.0
# 9                    山东省, 江苏省, 江西省, 河南省, 浙江省, 湖北省            6.0
# 10                             安徽省, 江苏省, 河北省, 河南省            4.0
# 11                          内蒙古自治区, 河北省, 河南省, 陕西省            4.0
# 12       广西壮族自治区, 江西省, 湖南省, 澳门特别行政区, 福建省, 香港特别行政区            6.0
# 13                             云南省, 广东省, 湖南省, 贵州省            4.0
# 14                                甘肃省, 西藏自治区, 青海省            3.0
# 15                             上海市, 安徽省, 山东省, 浙江省            4.0
# 16                   安徽省, 广东省, 浙江省, 湖北省, 湖南省, 福建省            6.0
# 17           内蒙古自治区, 北京市, 天津市, 山东省, 山西省, 河南省, 辽宁省            7.0
# 18                   安徽省, 山东省, 山西省, 河北省, 湖北省, 陕西省            6.0
# 19                        上海市, 安徽省, 江苏省, 江西省, 福建省            5.0
# 20                                                           0.0
# 21                   安徽省, 江西省, 河南省, 湖南省, 重庆市, 陕西省            6.0
# 22               广东省, 广西壮族自治区, 江西省, 湖北省, 贵州省, 重庆市            6.0
# 23                                            广东省            1.0
# 24       内蒙古自治区, 四川省, 宁夏回族自治区, 新疆维吾尔自治区, 陕西省, 青海省            6.0
# 25                                  广东省, 江西省, 浙江省            3.0
# 26                        云南省, 四川省, 新疆维吾尔自治区, 青海省            4.0
# 27                    云南省, 四川省, 广西壮族自治区, 湖南省, 重庆市            5.0
# 28                               内蒙古自治区, 吉林省, 河北省            3.0
# 29                        四川省, 湖北省, 湖南省, 贵州省, 陕西省            5.0
# 30  内蒙古自治区, 四川省, 宁夏回族自治区, 山西省, 河南省, 湖北省, 甘肃省, 重庆市            8.0
# 31                      四川省, 新疆维吾尔自治区, 甘肃省, 西藏自治区            4.0
# 32                                            广东省            1.0
# 33                                    内蒙古自治区, 吉林省            2.0

# %% [markdown]
# `apply()` 和 `map()` 类似，但是可以同时处理多列数据。此处我们用 `apply()` 来将每个省的确诊数据放入 `provinces` 中作为一列。

# %%
provinces['confirmed_cases'] = provinces['OWNER'].apply(lambda name: prov_confirm[name])

# %%
provinces
# Out:
#    OWNER                                           geometry  \
# 0     上海  MULTIPOLYGON (((121.42117 30.68613, 121.42240 ...
# 1     云南  POLYGON ((105.30025 27.70911, 105.29577 27.698...
# 2    内蒙古  POLYGON ((121.48938 53.33117, 121.49769 53.320...
# 3     北京  POLYGON ((117.37974 40.22687, 117.38528 40.223...
# 4     台湾  MULTIPOLYGON (((120.81553 21.75681, 120.81743 ...
# 5     吉林  POLYGON ((123.17773 46.24767, 123.18046 46.248...
# 6     四川  POLYGON ((105.49535 32.91074, 105.49502 32.905...
# 7     天津  MULTIPOLYGON (((117.69566 39.00026, 117.69897 ...
# 8     宁夏  MULTIPOLYGON (((106.05062 35.45260, 106.04993 ...
# 9     安徽  POLYGON ((116.36870 34.64072, 116.37081 34.639...
# 10    山东  MULTIPOLYGON (((120.85508 36.37765, 120.85657 ...
# 11    山西  POLYGON ((114.12488 40.74365, 114.13085 40.738...
# 12    广东  MULTIPOLYGON (((109.93091 20.22808, 109.93093 ...
# 13    广西  MULTIPOLYGON (((109.21333 20.89708, 109.21089 ...
# 14    新疆  POLYGON ((87.31262 49.10914, 87.31808 49.10807...
# 15    江苏  MULTIPOLYGON (((120.81194 33.01399, 120.81015 ...
# 16    江西  POLYGON ((118.18945 29.39522, 118.19344 29.386...
# 17    河北  MULTIPOLYGON (((119.14247 39.30547, 119.14012 ...
# 18    河南  MULTIPOLYGON (((111.00594 33.17101, 111.00577 ...
# 19    浙江  MULTIPOLYGON (((120.46658 27.16607, 120.46805 ...
# 20    海南  MULTIPOLYGON (((112.05676 3.85817, 112.05611 3...
# 21    湖北  MULTIPOLYGON (((110.97766 33.25967, 110.98971 ...
# 22    湖南  POLYGON ((113.94013 29.04828, 113.93997 29.044...
# 23    澳门  MULTIPOLYGON (((113.57883 22.16175, 113.57887 ...
# 24    甘肃  POLYGON ((97.17195 42.79342, 97.18481 42.77167...
# 25    福建  MULTIPOLYGON (((117.41612 23.56332, 117.41653 ...
# 26    西藏  POLYGON ((89.73125 36.08474, 89.72242 36.08345...
# 27    贵州  MULTIPOLYGON (((109.55247 26.72882, 109.54917 ...
# 28    辽宁  MULTIPOLYGON (((121.76275 41.00120, 121.77305 ...
# 29    重庆  POLYGON ((109.22860 29.12246, 109.22520 29.117...
# 30    陕西  POLYGON ((111.11640 39.36374, 111.11701 39.363...
# 31    青海  POLYGON ((92.40360 39.03967, 92.40493 39.04133...
# 32    香港  POLYGON ((114.22590 22.54496, 114.22630 22.543...
# 33   黑龙江  POLYGON ((121.48938 53.33117, 121.49162 53.331...
#
#                                         neighbors  neighbors_num  \
# 0                                        江苏省, 浙江省            2.0
# 1                        四川省, 广西壮族自治区, 西藏自治区, 贵州省            4.0
# 2     吉林省, 宁夏回族自治区, 山西省, 河北省, 甘肃省, 辽宁省, 陕西省, 黑龙江省            8.0
# 3                                        天津市, 河北省            2.0
# 4                                                            0.0
# 5                               内蒙古自治区, 辽宁省, 黑龙江省            3.0
# 6             云南省, 甘肃省, 西藏自治区, 贵州省, 重庆市, 陕西省, 青海省            7.0
# 7                                        北京市, 河北省            2.0
# 8                                内蒙古自治区, 甘肃省, 陕西省            3.0
# 9                    山东省, 江苏省, 江西省, 河南省, 浙江省, 湖北省            6.0
# 10                             安徽省, 江苏省, 河北省, 河南省            4.0
# 11                          内蒙古自治区, 河北省, 河南省, 陕西省            4.0
# 12       广西壮族自治区, 江西省, 湖南省, 澳门特别行政区, 福建省, 香港特别行政区            6.0
# 13                             云南省, 广东省, 湖南省, 贵州省            4.0
# 14                                甘肃省, 西藏自治区, 青海省            3.0
# 15                             上海市, 安徽省, 山东省, 浙江省            4.0
# 16                   安徽省, 广东省, 浙江省, 湖北省, 湖南省, 福建省            6.0
# 17           内蒙古自治区, 北京市, 天津市, 山东省, 山西省, 河南省, 辽宁省            7.0
# 18                   安徽省, 山东省, 山西省, 河北省, 湖北省, 陕西省            6.0
# 19                        上海市, 安徽省, 江苏省, 江西省, 福建省            5.0
# 20                                                           0.0
# 21                   安徽省, 江西省, 河南省, 湖南省, 重庆市, 陕西省            6.0
# 22               广东省, 广西壮族自治区, 江西省, 湖北省, 贵州省, 重庆市            6.0
# 23                                            广东省            1.0
# 24       内蒙古自治区, 四川省, 宁夏回族自治区, 新疆维吾尔自治区, 陕西省, 青海省            6.0
# 25                                  广东省, 江西省, 浙江省            3.0
# 26                        云南省, 四川省, 新疆维吾尔自治区, 青海省            4.0
# 27                    云南省, 四川省, 广西壮族自治区, 湖南省, 重庆市            5.0
# 28                               内蒙古自治区, 吉林省, 河北省            3.0
# 29                        四川省, 湖北省, 湖南省, 贵州省, 陕西省            5.0
# 30  内蒙古自治区, 四川省, 宁夏回族自治区, 山西省, 河南省, 湖北省, 甘肃省, 重庆市            8.0
# 31                      四川省, 新疆维吾尔自治区, 甘肃省, 西藏自治区            4.0
# 32                                            广东省            1.0
# 33                                    内蒙古自治区, 吉林省            2.0
#
#     confirmed_cases
# 0               635
# 1               184
# 2               193
# 3               593
# 4               420
# 5               104
# 6               561
# 7               189
# 8                75
# 9               991
# 10              787
# 11              197
# 12             1580
# 13              254
# 14               76
# 15              653
# 16              937
# 17              328
# 18             1276
# 19             1268
# 20              168
# 21            68128
# 22             1019
# 23               45
# 24              139
# 25              355
# 26                1
# 27              147
# 28              146
# 29              579
# 30              256
# 31               18
# 32             1025
# 33              898

# %% [markdown]
# #### `GeoDataFrame.plot` 方法参数
#
# - `column`：用于指定映射地图视觉元素的数值信息，可以是对应`GeoDataFrame`的列名，或是直接传入与几何对象一一对应得数值序列，默认为`None`
#
# - `cmap`：传入色彩方案
#
# - `categorical`：`bool`型，`True`表示指定映射目标列采取离散表示，对于数值型的列有意义，当对应目标列为类别型时自动变为`True`
#
# - `legend`：`bool`型，为`True`时会为地图添加图例
#
# - `scheme`：`str`型，用于指定地区分布图颜色的数值划分方案
#
# - `k`：`int`型，用于指定地图绘色的色阶数量
#
# - `vmin`,`vmax`：`None`或`float`，用于指定绘图的数值范围下限和上限，默认为`None`即以对应数据中的最小/大值为下限
#
# - `legend_kwds`：字典型，传入与图例相关的个性化参数
#
# - `classification_kwds`：字典型，传入与划分绘图颜色相关的个性化参数
#
# - `missing_kwds`：字典型，传入与缺失值处理相关的个性化参数，用于对缺失值部分的做个性化设置

# %% [markdown]
# - 地区分布图（Choropleth Map），指的是依据指定属性进行层次划分，并将对应的层次映射到对应几何对象的色彩之上。
#
# - 这里我们将各省的确诊病例数亩画成地区分布图。
#
# - 为了对确诊数量进行分级，我们需要使用上面提到的 `scheme` 参数。它会调用外部包 `mapclassify`。
#
# - `mapclassify` 提供多种分层方法，包括自然断点法（`NaturalBreaks`）、箱线图（`BoxPlot`）、等间距（`EqualInterval`）、分位数（`Quantiles`）和用户自定义（`Userdefined`）。
#
# - 我们使用用户自定义方式，将病例数分位 9，99，999，9999 等几档

# %%
# 请使用你的电脑上的字体文件
font_name = '/System/Library/Fonts/STHeiti Light.ttc'
myfont = mpl.font_manager.FontProperties(fname=font_name)
plt.rcParams["font.family"] = "Heiti TC"        # 字体文件名和字体名不同

fig,ax = plt.subplots(figsize=(12,12),subplot_kw={'projection': crs})
provinces.plot(ax=ax,column='confirmed_cases', cmap='Reds', legend=True, 
               scheme='UserDefined', classification_kwds={'bins':[10, 100, 500, 1000, 10000]},
               legend_kwds={'loc':'lower left','title':'累计确诊数量',
                            'shadow':True,'fancybox':True}, #'prop':{'font.family':'Heiti TC'}},
               transform=ccrs.PlateCarree())
#ax.background_patch.set_visible(False)
ax.outline_patch.set_visible(False)
#ax.axis('off')
ax.set_extent([75,130,15,54])

for index, row in provinces.iterrows():
    region = shorten_prov_names(row['OWNER'])

    ax.text(row.geometry.representative_point().x, row.geometry.representative_point().y,
            region, ha="center", va="center", size=6, transform=ccrs.Geodetic(),
            fontproperties=myfont)

# %% [markdown]
# #### 绘制疫情的南丁格尔玫瑰图 （Nightingale Rose)

# %%
import numpy as np

sorted_pro = provinces.sort_values(by='confirmed_cases',ascending=False)
cases = np.log(sorted_pro.confirmed_cases.values)
N = len(sorted_pro)
theta = np.arange(0,2*np.pi,2*np.pi/N)
width = 2*np.pi / (N)
num = sorted_pro.confirmed_cases
colors = plt.cm.plasma(num/np.max(num[1:]))

fig, ax = plt.subplots(figsize=(12,12),subplot_kw={'projection':'polar'})
ax.set_theta_zero_location("N")
bars = ax.bar(theta, cases, width=width, bottom=0, color=colors,alpha=0.5)
ax.axis('off')

rotations = np.rad2deg(theta)
for x, bar, rotation, label, label_num in zip(theta,
       bars, rotations, sorted_pro.OWNER.values, sorted_pro.confirmed_cases.values):
    lab = ax.text(x, bar.get_height(), label,
             ha='center', va='bottom', fontproperties=myfont,rotation=rotation, rotation_mode="anchor")
    lab = ax.text(x, bar.get_height()-0.2, str(label_num),
             ha='center', va='top', rotation=rotation, rotation_mode="anchor")
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# #### 课后练习
# - 返回的数据里有各个省级单位下面的市、县的数据。尝试画一画你所在省的确诊病例分布图（如果需要市、县级地图，可以联系我）。
#
# - https://view.inews.qq.com/g2/getOnsInfo?name=disease_foreign 返回国外病例数据。尝试画一画世界的病例分布。

# %% [markdown]
# ## References
#
# https://www.cnblogs.com/feffery/p/12361421.html (强烈推荐此博客的文章)
